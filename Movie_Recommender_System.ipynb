# %%
#importing

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#dataset
column_names=['UserID', 'ItemID', 'Rating', 'Time']
dataset=pd.read_csv(r'/content/u.data', sep='\t', names=column_names)
col_names=['ItemID', 'Title']
movie_titles=pd.read_csv(r'/content/Movie_Titles')

# %%
dataset.shape
# Out:
# (100003, 4)

# %%
dataset.head()
# Out:
#    UserID  ItemID  Rating       Time
# 0       0      50       5  881250949
# 1       0     172       5  881250949
# 2       0     133       1  881250949
# 3     196     242       3  881250949
# 4     186     302       3  891717742

# %%
dataset.describe
# Out:
# <bound method NDFrame.describe of         UserID  ItemID  Rating       Time
# 0            0      50       5  881250949
# 1            0     172       5  881250949
# 2            0     133       1  881250949
# 3          196     242       3  881250949
# 4          186     302       3  891717742
# ...        ...     ...     ...        ...
# 99998      880     476       3  880175444
# 99999      716     204       5  879795543
# 100000     276    1090       1  874795795
# 100001      13     225       2  882399156
# 100002      12     203       3  879959583
#
# [100003 rows x 4 columns]>

# %%
dataset.isnull().sum()
# Out:
# UserID    0
# ItemID    0
# Rating    0
# Time      0
# dtype: int64

# %%
movie_titles.shape
# Out:
# (1682, 2)

# %%
movie_titles.head()
# Out:
#    ItemID              Title
# 0       1   Toy Story (1995)
# 1       2   GoldenEye (1995)
# 2       3  Four Rooms (1995)
# 3       4  Get Shorty (1995)
# 4       5     Copycat (1995)

# %%
movie_titles.describe()
# Out:
#             ItemID
# count  1682.000000
# mean    841.500000
# std     485.695893
# min       1.000000
# 25%     421.250000
# 50%     841.500000
# 75%    1261.750000
# max    1682.000000

# %%
movie_titles.isnull().sum()
# Out:
# ItemID    0
# Title     0
# dtype: int64

# %%
#dataset=dataset.astype('str')

# %%
#movie_titles=movie_titles.astype('str')

# %%
data=pd.merge(dataset, movie_titles, on='ItemID')

# %%
data.head()
# Out:
#    UserID  ItemID  Rating       Time             Title
# 0       0      50       5  881250949  Star Wars (1977)
# 1     290      50       5  880473582  Star Wars (1977)
# 2      79      50       4  891271545  Star Wars (1977)
# 3       2      50       5  888552084  Star Wars (1977)
# 4       8      50       5  879362124  Star Wars (1977)

# %%
#grouping
#data=data.groupby('Title')

# %%
#data.head()

# %%
#finding the average rating of each movie
data.groupby('Title')['Rating'].mean().sort_values(ascending=False).head()
# Out:
# Title
# Marlene Dietrich: Shadow and Light (1996)     5.0
# Prefontaine (1997)                            5.0
# Santa with Muscles (1996)                     5.0
# Star Kid (1997)                               5.0
# Someone Else's America (1995)                 5.0
# Name: Rating, dtype: float64

# %%
data.groupby('Title')['Rating'].count().sort_values(ascending=False).head()
# Out:
# Title
# Star Wars (1977)             584
# Contact (1997)               509
# Fargo (1996)                 508
# Return of the Jedi (1983)    507
# Liar Liar (1997)             485
# Name: Rating, dtype: int64

# %%
ratings=pd.DataFrame(data.groupby('Title')['Rating'].mean())

# %%
ratings.head()
# Out:
#                              Rating
# Title
# 'Til There Was You (1997)  2.333333
# 1-900 (1994)               2.600000
# 101 Dalmatians (1996)      2.908257
# 12 Angry Men (1957)        4.344000
# 187 (1997)                 3.024390

# %%
ratings=pd.merge(ratings,data.groupby('Title')['Rating'].count(),on='Title')

# %%
ratings.head()
# Out:
#                            Rating_x  Rating_y
# Title
# 'Til There Was You (1997)  2.333333         9
# 1-900 (1994)               2.600000         5
# 101 Dalmatians (1996)      2.908257       109
# 12 Angry Men (1957)        4.344000       125
# 187 (1997)                 3.024390        41

# %%
ratings.rename(columns = {'Rating_y':'Count'}, inplace = True)
ratings.rename(columns = {'Rating_x':'Rating_avg'}, inplace = True)

# %%
ratings.head()
# Out:
#                            Rating_avg  Count
# Title
# 'Til There Was You (1997)    2.333333      9
# 1-900 (1994)                 2.600000      5
# 101 Dalmatians (1996)        2.908257    109
# 12 Angry Men (1957)          4.344000    125
# 187 (1997)                   3.024390     41

# %%
ratings.sort_values('Count',ascending=False)
# Out:
#                                     Rating_avg  Count
# Title
# Star Wars (1977)                      4.359589    584
# Contact (1997)                        3.803536    509
# Fargo (1996)                          4.155512    508
# Return of the Jedi (1983)             4.007890    507
# Liar Liar (1997)                      3.156701    485
# ...                                        ...    ...
# Great Day in Harlem, A (1994)         5.000000      1
# Other Voices, Other Rooms (1997)      3.000000      1
# Good Morning (1971)                   1.000000      1
# Girls Town (1996)                     3.000000      1
# Á köldum klaka (Cold Fever) (1994)    3.000000      1
#
# [1664 rows x 2 columns]

# %%
ratings.sort_values('Rating_avg',ascending=False)
# Out:
#                                               Rating_avg  Count
# Title
# They Made Me a Criminal (1939)                       5.0      1
# Marlene Dietrich: Shadow and Light (1996)            5.0      1
# Saint of Fort Washington, The (1993)                 5.0      2
# Someone Else's America (1995)                        5.0      1
# Star Kid (1997)                                      5.0      3
# ...                                                  ...    ...
# Eye of Vichy, The (Oeil de Vichy, L') (1993)         1.0      1
# King of New York (1990)                              1.0      1
# Touki Bouki (Journey of the Hyena) (1973)            1.0      1
# Bloody Child, The (1996)                             1.0      1
# Crude Oasis, The (1995)                              1.0      1
#
# [1664 rows x 2 columns]

# %%
ratings.round({"Rating_avg":2})
# Out:
#                                        Rating_avg  Count
# Title
# 'Til There Was You (1997)                    2.33      9
# 1-900 (1994)                                 2.60      5
# 101 Dalmatians (1996)                        2.91    109
# 12 Angry Men (1957)                          4.34    125
# 187 (1997)                                   3.02     41
# ...                                           ...    ...
# Young Guns II (1990)                         2.77     44
# Young Poisoner's Handbook, The (1995)        3.34     41
# Zeus and Roxanne (1997)                      2.17      6
# unknown                                      3.44      9
# Á köldum klaka (Cold Fever) (1994)           3.00      1
#
# [1664 rows x 2 columns]

# %%
Movie_matrix=data.pivot_table(index='UserID', columns='Title', values='Rating')

# %%
Movie_matrix.head()
# Out:
# Title   'Til There Was You (1997)  ...  Á köldum klaka (Cold Fever) (1994)
# UserID                             ...
# 0                             NaN  ...                                 NaN
# 1                             NaN  ...                                 NaN
# 2                             NaN  ...                                 NaN
# 3                             NaN  ...                                 NaN
# 4                             NaN  ...                                 NaN
#
# [5 rows x 1664 columns]
# Warning: Total number of columns (1664) exceeds max_columns (20) limiting to first (20) columns.

# %%
name=input()
# Out:
# 12 Angry Men (1957)

# %%
similarity=Movie_matrix.corrwith(Movie_matrix[name])
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)

# %%
recommendation_matrix=pd.DataFrame(similarity, columns=['Correlation_Score'])

# %%
recommendation_matrix
# Out:
#                                        Correlation_Score
# Title
# 'Til There Was You (1997)                      -0.500000
# 1-900 (1994)                                         NaN
# 101 Dalmatians (1996)                          -0.049890
# 12 Angry Men (1957)                             1.000000
# 187 (1997)                                      0.666667
# ...                                                  ...
# Young Guns II (1990)                           -0.361961
# Young Poisoner's Handbook, The (1995)           0.144338
# Zeus and Roxanne (1997)                         1.000000
# unknown                                         1.000000
# Á köldum klaka (Cold Fever) (1994)                   NaN
#
# [1664 rows x 1 columns]

# %%
n=int(input())
# Out:
# 5

# %%
recommendation_matrix=recommendation_matrix.dropna()

# %%
recommendation_matrix
# Out:
#                                        Correlation_Score
# Title
# 'Til There Was You (1997)                      -0.500000
# 101 Dalmatians (1996)                          -0.049890
# 12 Angry Men (1957)                             1.000000
# 187 (1997)                                      0.666667
# 2 Days in the Valley (1996)                     0.256625
# ...                                                  ...
# Young Guns (1988)                               0.068944
# Young Guns II (1990)                           -0.361961
# Young Poisoner's Handbook, The (1995)           0.144338
# Zeus and Roxanne (1997)                         1.000000
# unknown                                         1.000000
#
# [1188 rows x 1 columns]

# %%
recommendation_matrix=recommendation_matrix.sort_values('Correlation_Score',ascending=False)

# %%
recommendation_matrix
# Out:
#                                             Correlation_Score
# Title
# Dingo (1992)                                              1.0
# Nina Takes a Lover (1994)                                 1.0
# Surviving Picasso (1996)                                  1.0
# American Dream (1990)                                     1.0
# FairyTale: A True Story (1997)                            1.0
# ...                                                       ...
# Children of the Corn: The Gathering (1996)               -1.0
# For Richer or Poorer (1997)                              -1.0
# Heaven's Prisoners (1996)                                -1.0
# House Arrest (1996)                                      -1.0
# Hellraiser: Bloodline (1996)                             -1.0
#
# [1188 rows x 1 columns]

# %%
#for i in range(n):
 # if(name in recommendation_matrix.iloc['Title']):
  #  continue
  #else:
   # print(recommendation_matrix['Title'])

# %%
recommendation_matrix=pd.merge(recommendation_matrix, ratings, on='Title')

# %%
recommendation_matrix
# Out:
#                                             Correlation_Score  ...  Count
# Title                                                          ...
# Dingo (1992)                                              1.0  ...      5
# Nina Takes a Lover (1994)                                 1.0  ...      6
# Surviving Picasso (1996)                                  1.0  ...     19
# American Dream (1990)                                     1.0  ...      2
# FairyTale: A True Story (1997)                            1.0  ...     30
# ...                                                       ...  ...    ...
# Children of the Corn: The Gathering (1996)               -1.0  ...     19
# For Richer or Poorer (1997)                              -1.0  ...     14
# Heaven's Prisoners (1996)                                -1.0  ...     27
# House Arrest (1996)                                      -1.0  ...     25
# Hellraiser: Bloodline (1996)                             -1.0  ...     18
#
# [1188 rows x 3 columns]

# %%
recommendation_matrix.shape
# Out:
# (1188, 3)

# %%
recommendation_matrix=recommendation_matrix.dropna()

# %%
recommendation_matrix.shape
# Out:
# (1188, 3)

# %%
#recommendation_matrix=recommendation_matrix.drop(recommendation_matrix[recommendation_matrix['Count']<100].index,inplace=True)

# %%
recommendation_matrix=recommendation_matrix[recommendation_matrix['Count']>100].sort_values('Correlation_Score',ascending=False).head()

# %%
recommendation_matrix.shape
# Out:
# (5, 3)

# %%
recommendation_matrix[1:]
# Out:
#                              Correlation_Score  Rating_avg  Count
# Title
# Ulee's Gold (1997)                    0.619544    3.760870    184
# Rear Window (1954)                    0.570513    4.387560    209
# Seven Years in Tibet (1997)           0.549939    3.458065    155
# Clerks (1994)                         0.528173    3.804054    148
